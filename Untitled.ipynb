# %%
import pandas as pd
df = pd.read_csv("MOCK_DATA.csv")

df.head()
df.dtypes
# Out:
# id           int64
# group          str
# in_stock    object
# color          str
# isbn           str
# city           str
# dtype: object

# %%
type_mapping = {
    "int64": "id",
    "str": "group",
    "object": "in_stock",
    "str": "color",
    "str": "isbn",
    "str": "city", 
}
